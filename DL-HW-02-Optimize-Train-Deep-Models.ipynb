---------------- Val_Acc: 80.80%, Val_Loss: 0.54799080
# epoch: 18 -> Accuracy: 83.86%, Loss: 0.48084861 ---------------- Val_Acc: 81.00%, Val_Loss: 0.53393841
# epoch: 19 -> Accuracy: 84.46%, Loss: 0.46304965 ---------------- Val_Acc: 81.60%, Val_Loss: 0.52230698
# epoch: 20 -> Accuracy: 84.92%, Loss: 0.44744045 ---------------- Val_Acc: 82.20%, Val_Loss: 0.51253402
# epoch: 21 -> Accuracy: 85.32%, Loss: 0.43354765 ---------------- Val_Acc: 82.40%, Val_Loss: 0.50428164
# epoch: 22 -> Accuracy: 85.64%, Loss: 0.42106256 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49730524
# epoch: 23 -> Accuracy: 86.00%, Loss: 0.40975380 ---------------- Val_Acc: 83.20%, Val_Loss: 0.49132779
# epoch: 24 -> Accuracy: 86.28%, Loss: 0.39941600 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48617533
# epoch: 25 -> Accuracy: 86.61%, Loss: 0.38991123 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48169667
# epoch: 26 -> Accuracy: 86.89%, Loss: 0.38111496 ---------------- Val_Acc: 83.70%, Val_Loss: 0.47779340
# epoch: 27 -> Accuracy: 87.18%, Loss: 0.37292975 ---------------- Val_Acc: 83.60%, Val_Loss: 0.47439647
# epoch: 28 -> Accuracy: 87.36%, Loss: 0.36526754 ---------------- Val_Acc: 83.40%, Val_Loss: 0.47145891
# epoch: 29 -> Accuracy: 87.59%, Loss: 0.35807091 ---------------- Val_Acc: 83.60%, Val_Loss: 0.46891040
# epoch: 30 -> Accuracy: 87.84%, Loss: 0.35127783 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46671987
# epoch: 31 -> Accuracy: 88.06%, Loss: 0.34484786 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46480390
# epoch: 32 -> Accuracy: 88.30%, Loss: 0.33873680 ---------------- Val_Acc: 83.90%, Val_Loss: 0.46315405
# epoch: 33 -> Accuracy: 88.51%, Loss: 0.33291170 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46172655
# epoch: 34 -> Accuracy: 88.68%, Loss: 0.32734692 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46047717
# epoch: 35 -> Accuracy: 88.77%, Loss: 0.32201678 ---------------- Val_Acc: 84.10%, Val_Loss: 0.45941666
# epoch: 36 -> Accuracy: 88.97%, Loss: 0.31690234 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45856085
# epoch: 37 -> Accuracy: 89.13%, Loss: 0.31198615 ---------------- Val_Acc: 84.80%, Val_Loss: 0.45784882
# epoch: 38 -> Accuracy: 89.30%, Loss: 0.30725285 ---------------- Val_Acc: 84.60%, Val_Loss: 0.45727220
# epoch: 39 -> Accuracy: 89.49%, Loss: 0.30267859 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45683849
# epoch: 40 -> Accuracy: 89.60%, Loss: 0.29826099 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45652449
# Training time in second: 295.43889005400024

# %% [markdown]
# We can now plot these results.

# %%
def plot_learning_acc_and_loss(loss_tr, acc_tr, loss_val, acc_val):
    info = {'loss_training': loss_tr, 'acc_training': acc_tr, 'loss_validation': loss_val, 'acc_validation': acc_val}
    df = pd.DataFrame(info)
    df.plot(figsize=(8, 10), subplots=[('acc_training', 'acc_validation'), ('loss_training','loss_validation')], grid=True)
    plt.xlabel("Epochs")
    plt.show()
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# ### **[TO COMPLETE]**: Evaluate the model
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set. By having a look at the previous code, compute the performances on the test set.

# %% [markdown]
# `%STARTCODE`

# %%
###########################################################
### [TO COMPLETE]: START ###
# We define a function to evaluate a model on the test set in order to avoid redudant code
def evaluate_model_test(model, dataloader_test):
    model.eval()
    total_acc_test, total_count_test, n_batches_test, total_loss_test = 0, 0, 0, 0
    # Create empty lists to store test loss and accuracy values
    loss_test, acc_test = [], []
    for idx, (label, text) in enumerate(dataloader_test):
        # Forward pass to get logits
        logits = model(text)
        # Compute the loss using the specified criterion
        loss = criterion(logits, label)
        # Increment the total loss and accuracy for this batch
        total_loss_test += loss
        total_acc_test += (logits.argmax(1) == label).sum().item()
        # Keep track of the total number of labels seen so far
        total_count_test += label.size(0)
        # Increment the total number of batches seen so far
        n_batches_test += 1
        # Compute the average loss for this batch and append it to the loss list
        avg_loss_test = total_loss_test / n_batches_test
        loss_test.append(avg_loss_test.item())
        # Compute the accuracy for this batch and append it to the accuracy list
        accuracy_test = total_acc_test / total_count_test
        acc_test.append(accuracy_test)
    return avg_loss_test, accuracy_test
### [TO COMPLETE]: END ###
###########################################################

# %%
###########################################################
### [TO COMPLETE]: START ###
avg_loss_test, accuracy_test = evaluate_model_test(model, dataloader_test)
### [TO COMPLETE]: END ###
###########################################################
print(f"Test loss: {avg_loss_test:.8f}", end=' ---------- ')
print(f"Test accuracy: {100*accuracy_test:.4f}%")
# Out:
# Test loss: 0.44434321 ---------- Test accuracy: 84.3000%

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in the next cell.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **Answer**:
#
# Selecting a suitable model and setting the **hyperparameters** is crucial for achieving the best results in deep learning. However, this can be challenging as it depends on the data being used. This is where the **validation** set comes into play. The latter represents a separate set of data that is not used during training, but instead is used to evaluate the performance of the model and tune the **hyperparameters**. During training, the model is evaluated on the **validation** set at each epoch to monitor the loss and accuracy trends.
#
# On the other hand, the **test** set is used to obtain a reliable estimation of the model's generalization error and establish its correctness on new, unseen data. The **validation** set is usually smaller and cannot guarantee accurate results, as it is involved in each iteration to determine the trend of the model's loss and accuracy. However, the **test** set is used only at the end of the training process to obtain an estimate of the true values of error and accuracy, which are crucial for establishing the reliability of the model and correctness of the algorithm. By evaluating the model on the **test** set, we can obtain a more reliable assessment of how well the model is likely to perform in real-world scenarios.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not much overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %% [markdown]
# ## **[TO COMPLETE]**: Overfitting Model
# In the next cell define a new model (similar to the previous one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %% [markdown]
# `%STARTCODE`

# %%
###########################################################
### [TO COMPLETE]: START ###
# To create a new model that overfits the training data, we can increase the capacity of the model by augmenting the number of neurons in the existing layers
# In addition, we could also add an additional hidden layer to overfit the dataset almost surely
EPOCHS = 40 # same number of epochs
lr = 1e-4 # same learning rate
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[512, 256, 128]).to(device) # increased number of parameters
### [TO COMPLETE]: END ###
###########################################################
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       512,512
# │    └─Linear: 2-2                       131,328
# │    └─Linear: 2-3                       32,896
# │    └─Linear: 2-4                       516
# =================================================================
# Total params: 677,252
# Trainable params: 677,252
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 33.54%, Loss: 1.36157990 ---------------- Val_Acc: 45.50%, Val_Loss: 1.24127424
# epoch: 2 -> Accuracy: 54.47%, Loss: 1.13980389 ---------------- Val_Acc: 59.10%, Val_Loss: 1.06335020
# epoch: 3 -> Accuracy: 66.56%, Loss: 0.94055074 ---------------- Val_Acc: 68.70%, Val_Loss: 0.89185226
# epoch: 4 -> Accuracy: 73.72%, Loss: 0.76380312 ---------------- Val_Acc: 73.10%, Val_Loss: 0.75996727
# epoch: 5 -> Accuracy: 78.25%, Loss: 0.63521564 ---------------- Val_Acc: 75.70%, Val_Loss: 0.67614305
# epoch: 6 -> Accuracy: 81.23%, Loss: 0.54766852 ---------------- Val_Acc: 77.70%, Val_Loss: 0.62301141
# epoch: 30 -> Accuracy: 99.49%, Loss: 0.05120615 ---------------- Val_Acc: 82.90%, Val_Loss: 0.63480419
# epoch: 31 -> Accuracy: 99.62%, Loss: 0.04542653 ---------------- Val_Acc: 83.00%, Val_Loss: 0.64672792
# epoch: 32 -> Accuracy: 99.67%, Loss: 0.04027073 ---------------- Val_Acc: 83.10%, Val_Loss: 0.65877295
# epoch: 33 -> Accuracy: 99.76%, Loss: 0.03568865 ---------------- Val_Acc: 83.10%, Val_Loss: 0.67038184
# epoch: 34 -> Accuracy: 99.80%, Loss: 0.03164611 ---------------- Val_Acc: 83.10%, Val_Loss: 0.68219465
# epoch: 35 -> Accuracy: 99.82%, Loss: 0.02811071 ---------------- Val_Acc: 83.40%, Val_Loss: 0.69424033
# epoch: 36 -> Accuracy: 99.86%, Loss: 0.02502222 ---------------- Val_Acc: 83.50%, Val_Loss: 0.70665771
# epoch: 37 -> Accuracy: 99.95%, Loss: 0.02232184 ---------------- Val_Acc: 83.50%, Val_Loss: 0.71931791
# epoch: 38 -> Accuracy: 99.96%, Loss: 0.01997499 ---------------- Val_Acc: 83.50%, Val_Loss: 0.73171902
# epoch: 39 -> Accuracy: 99.98%, Loss: 0.01792843 ---------------- Val_Acc: 83.50%, Val_Loss: 0.74402684
# epoch: 40 -> Accuracy: 99.98%, Loss: 0.01614780 ---------------- Val_Acc: 83.40%, Val_Loss: 0.75575864
# Training time in second: 280.9371333570002

# %%
# This should produce a plot where the training loss decreases rapidly and the validation loss starts to increase at a certain epoch
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.3: $L^1$- and $L^2$-regularization
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \lambda L^p(\theta)
# $$
# where $\lambda$ is a hyperparameter that weighs the relative contribution of the norm penalty $L^p$ on a lernable parameter vector $\theta$:
# $$
#  L^p(\theta)=||\theta||_p=\left(\sum_i |\theta_i|^p\right)^{1/p}
# $$

# %% [markdown]
# In the following blocks you should implement both the $L^1$ and $L^2$ regularization for the overfitting model.
#
# **Disclaimer**: you can implement norms either from scratch (i.e. using simple math operators) or using `torch.linalg` methods, but **not** using implementations embedded in Torch optimizers.

# %% [markdown]
# ### **[TO COMPLETE]**: $L^1$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L1(model, optimizer, dataloader_train, dataloader_val, l1_lambda=1e-3, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []

  for epoch in range(EPOCHS):
    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      ### [TO COMPLETE]: START ###
      # Add L1 regularization from scratch
      l1_norm = 0.0
      for param in model.parameters():
        l1_norm += torch.abs(param).sum() # sum of parameters absolute values
      loss_with_l1 = loss + l1_lambda * l1_norm
      ### [TO COMPLETE]: END ###
      ##########################################################
      total_loss_train += loss
      loss_with_l1.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train / n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train / total_count_train
    acc_train.append(accuracy_train)

    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val / n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val / total_count_val
    acc_val.append(accuracy_val)
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L1(overfit_model, optimizer, dataloader_training, dataloader_validation, l1_lambda=0.001)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 28.81%, Loss: 1.37630403 ---------------- Val_Acc: 33.50%, Val_Loss: 1.36279845
# epoch: 2 -> Accuracy: 33.95%, Loss: 1.35908866 ---------------- Val_Acc: 38.40%, Val_Loss: 1.34745193
# epoch: 3 -> Accuracy: 38.81%, Loss: 1.34167659 ---------------- Val_Acc: 43.00%, Val_Loss: 1.32921696
# epoch: 4 -> Accuracy: 43.91%, Loss: 1.31956279 ---------------- Val_Acc: 47.50%, Val_Loss: 1.30501997
# epoch: 5 -> Accuracy: 48.13%, Loss: 1.28928363 ---------------- Val_Acc: 51.30%, Val_Loss: 1.27177846
# epoch: 6 -> Accuracy: 51.66%, Loss: 1.24836576 ---------------- Val_Acc: 54.70%, Val_Loss: 1.22685027
# epoch: 32 -> Accuracy: 86.41%, Loss: 0.44184110 ---------------- Val_Acc: 82.60%, Val_Loss: 0.52337015
# epoch: 33 -> Accuracy: 86.62%, Loss: 0.43692619 ---------------- Val_Acc: 82.90%, Val_Loss: 0.52012098
# epoch: 34 -> Accuracy: 86.75%, Loss: 0.43236533 ---------------- Val_Acc: 82.80%, Val_Loss: 0.51710361
# epoch: 35 -> Accuracy: 86.92%, Loss: 0.42813021 ---------------- Val_Acc: 82.80%, Val_Loss: 0.51430684
# epoch: 36 -> Accuracy: 87.07%, Loss: 0.42417690 ---------------- Val_Acc: 82.90%, Val_Loss: 0.51171482
# epoch: 37 -> Accuracy: 87.20%, Loss: 0.42044273 ---------------- Val_Acc: 83.00%, Val_Loss: 0.50919169
# epoch: 38 -> Accuracy: 87.34%, Loss: 0.41693577 ---------------- Val_Acc: 83.00%, Val_Loss: 0.50686687
# epoch: 39 -> Accuracy: 87.47%, Loss: 0.41366616 ---------------- Val_Acc: 83.40%, Val_Loss: 0.50470072
# epoch: 40 -> Accuracy: 87.52%, Loss: 0.41060719 ---------------- Val_Acc: 83.40%, Val_Loss: 0.50272906
# Training time in second: 285.03174629299974

# %%
# This should produce a plot in which the regularized validation loss should follow better the training loss w.r.t the L1 seen previously
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.4: Early Stopping
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (a.k.a. the "patience" or "tolerance" hyper-parameter), it stops the training phase.
#
# To implement it in PyTorch, we define a simple classes that does this job.

# %%
class EarlyStopping:
    def __init__(self, tolerance, min_delta):
        self.tolerance = tolerance
        self.min_delta = min_delta
        self.counter = 0
        self.early_stop = False

    def __call__(self, train_loss, validation_loss):
        if (validation_loss - train_loss) > self.min_delta:
            self.counter += 1
            if self.counter >= self.tolerance:
                self.early_stop = True

# %% [markdown]
# ## **[TO COMPLETE]**: Define training procedure
# Define a training procedure with Early Stopping and check its performances.

# %% [markdown]
# `%STARTCODE`

# %%
def train_early_stop(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  ###########################################################
  ### [TO COMPLETE]: START ###
  # Instantiate an object of the EarlyStopping class
  early_stopping = EarlyStopping(tolerance=8, min_delta=0.001)
  ### [TO COMPLETE]: END ###
  ###########################################################
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []

  for epoch in range(EPOCHS):
    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train / n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train / total_count_train
    acc_train.append(accuracy_train)

    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val / n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val / total_count_val
    acc_val.append(accuracy_val)
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
    ############################################################
    ### [TO COMPLETE]: START ####
    # Use the EarlyStopping object
    early_stopping(avg_loss_train, avg_loss_val)
    if early_stopping.early_stop: # condition to stop the training process
      print(f"Early stopping: training stopped early at epoch {epoch+1}")
      break
    ### [TO COMPLETE]: END ####
    ############################################################
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_early_stop(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 31.27%, Loss: 1.36401975 ---------------- Val_Acc: 39.30%, Val_Loss: 1.33295572
# epoch: 2 -> Accuracy: 46.87%, Loss: 1.29101884 ---------------- Val_Acc: 49.80%, Val_Loss: 1.25915432
# epoch: 3 -> Accuracy: 58.32%, Loss: 1.19189310 ---------------- Val_Acc: 60.20%, Val_Loss: 1.14494801
# epoch: 4 -> Accuracy: 66.55%, Loss: 1.04773700 ---------------- Val_Acc: 67.20%, Val_Loss: 0.99001509
# epoch: 5 -> Accuracy: 72.64%, Loss: 0.87837327 ---------------- Val_Acc: 71.20%, Val_Loss: 0.83485866
# epoch: 6 -> Accuracy: 76.72%, Loss: 0.72818732 ---------------- Val_Acc: 73.90%, Val_Loss: 0.71944463
# epoch: 7 -> Accuracy: 79.47%, Loss: 0.62026852 ---------------- Val_Acc: 76.50%, Val_Loss: 0.64668214
# epoch: 8 -> Accuracy: 81.53%, Loss: 0.54734176 ---------------- Val_Acc: 78.50%, Val_Loss: 0.60134697
# epoch: 11 -> Accuracy: 98.41%, Loss: 0.07860555 ---------------- Val_Acc: 82.60%, Val_Loss: 0.64661789
# epoch: 12 -> Accuracy: 99.05%, Loss: 0.06232735 ---------------- Val_Acc: 83.40%, Val_Loss: 0.66515720
# epoch: 13 -> Accuracy: 99.17%, Loss: 0.05204901 ---------------- Val_Acc: 83.90%, Val_Loss: 0.69464809
# epoch: 14 -> Accuracy: 99.09%, Loss: 0.04817122 ---------------- Val_Acc: 83.80%, Val_Loss: 0.73103768
# epoch: 15 -> Accuracy: 98.65%, Loss: 0.05102818 ---------------- Val_Acc: 82.50%, Val_Loss: 0.78773654
# --------------------------------------------------

# %%
# Let's plot the results
for idx, el in enumerate(stack):
  print(f"Learning Rate: {learning_rates[idx]}")
  plot_learning_acc_and_loss(*el)
# Out:
# Learning Rate: 1e-05
# Learning Rate: 0.0001
# Learning Rate: 0.001

# %% [markdown]
# # Exercise 2.5: Grid Search
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider different possible combinations of values for each hyper-parameter. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be selected.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`, together with some classes from the `skorch` package which allows to use PyTorch models with `scikit-learn`.

# %%
model = NeuralNetClassifier(
    module=FeedforwardNetwork,
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.Adam,
    max_epochs=2)

# We need to adapt PyTorch Dataset to work with scikit-learn GridSearchCV
# We use the SliceDataset class from skorch package for this purpose
X_slice = SliceDataset(train_dataset, idx=1)
y_slice = SliceDataset(train_dataset, idx=0)

# %% [markdown]
# ## **[TO COMPLETE]**: Define hyperparameters grid

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use dictionaries of very limited size and hyperparameters, but in a real-world scenario a reasonable amount of possible values should be considered (and there are many other approaches beside Grid-Search).

# %% [markdown]
# `%STARTCODE`

# %%
###########################################################
### [TO COMPLETE]: START ###
params = {
    'lr': [1e-5, 1e-4, 1e-3],
    'module__input_dim': [1000], # input dimensions of the data should be fixed
    'module__num_classes': [4], # number of classes should be fixed
    'module__hidden_layers_dim': [[256, 128], [128, 64], [64, 64], [64, 32]],
    }
### [TO COMPLETE]: END ###
###########################################################

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Now you can use `sklearn`'s `GridSearchCV` to search the hyperparameter space of the `NeuralNetClassifier`:

# %%
n_jobs = multiprocessing.cpu_count() - 1
gs = GridSearchCV(model, params, n_jobs=n_jobs)

# %%
outputs = gs.fit(X_slice, y_slice)
# Out:
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.4215       0.2437        1.4246  10.8070
#       2        1.4070       0.2594        1.4118  10.9009
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.4868       0.2869        1.4615  11.1678
#       2        1.4461       0.2938        1.4274  11.1463
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.4384       0.2450        1.4442  11.1437
#       2        1.4165       0.2619        1.4262  11.0766
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.4464       0.2569        1.4357  10.9239
#       2        1.4252       0.2637        1.4188  10.6819
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.4513       0.2425        1.4426  10.9272
#       2        1.4257       0.2569        1.4216  9.0507
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.4025       0.2469        1.4054  10.6100
#       2        1.3966       0.2550        1.4000  9.0572
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3930       0.2762        1.3881  9.0567
#       2        1.3890       0.2800        1.3848  10.5380
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.4008       0.2519        1.3978  9.0977
#       2        1.3952       0.2575        1.3930  10.7710
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3886       0.2675        1.3922  10.8256
#       2        1.3817       0.2819        1.3863  10.8545
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.4064       0.2475        1.4052  10.8390
#       2        1.4005       0.2537        1.4002  10.9157
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3976       0.2606        1.3943  10.9776
#       2        1.3935       0.2662        1.3906  10.4023
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3914       0.2750        1.3900  11.1129
#       2        1.3889       0.2769        1.3878  9.0159
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3927       0.2612        1.3899  11.0664
#       2        1.3900       0.2644        1.3877  9.1425
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3872       0.2631        1.3865  10.1606
#       2        1.3854       0.2681        1.3850  9.7268
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.4003       0.2356        1.3976  9.0230
#       2        1.3975       0.2419        1.3952  11.0021
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3900       0.2756        1.3879  9.1622
#       2        1.3883       0.2769        1.3863  11.1456
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3930       0.2531        1.3892  10.2644
#       2        1.3913       0.2512        1.3878  11.0136
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3840       0.2706        1.3825  10.9352
#       2        1.3825       0.2775        1.3812  10.9763
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3914       0.2500        1.3882  11.1199
#       2        1.3894       0.2506        1.3865  10.9954
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3894       0.2500        1.3890  10.7885
#       2        1.3882       0.2569        1.3880  10.7645
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3769       0.3719        1.3261  11.0072
#       2        1.2630       0.5106        1.2238  11.0439
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.2955       0.6675        1.1174  10.6580
#       2        0.7691       0.7975        0.5803  10.8952
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.2890       0.6950        1.1035  11.1481
#       2        0.7525       0.8100        0.5666  11.1320
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3115       0.6275        1.1514  10.9785
#       2        0.7976       0.7887        0.5995  11.0413
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.2957       0.6913        1.1024  11.0474
#       2        0.7808       0.7869        0.6041  10.5059
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.9319       0.7935        0.5843  13.4405
#       2        0.4208       0.8255        0.5060  13.4481

# %% [markdown]
# ## **[TO COMPLETE]**: Visualize results
# Print the best hyper-parameters and the performances on the best model on the test set.

# %% [markdown]
# `%STARTCODE`

# %%
###########################################################
### [TO COMPLETE]: START ###
print("Scores for all hyperparameters combinations:")
for i in range(len(outputs.cv_results_['params'])):
    print(f"{outputs.cv_results_['params'][i]}: {outputs.cv_results_['mean_test_score'][i]}")
### [TO COMPLETE]: END ###
###########################################################
# Out:
# Scores for all hyperparameters combinations:
# {'lr': 1e-05, 'module__hidden_layers_dim': [256, 128], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.26870000000000005
# {'lr': 1e-05, 'module__hidden_layers_dim': [128, 64], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.264
# {'lr': 1e-05, 'module__hidden_layers_dim': [64, 64], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.2584
# {'lr': 1e-05, 'module__hidden_layers_dim': [64, 32], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.26359999999999995
# {'lr': 0.0001, 'module__hidden_layers_dim': [256, 128], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.4968
# {'lr': 0.0001, 'module__hidden_layers_dim': [128, 64], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.42400000000000004
# {'lr': 0.0001, 'module__hidden_layers_dim': [64, 64], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.3693
# {'lr': 0.0001, 'module__hidden_layers_dim': [64, 32], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.3355
# {'lr': 0.001, 'module__hidden_layers_dim': [256, 128], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.8210000000000001
# {'lr': 0.001, 'module__hidden_layers_dim': [128, 64], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.8176
# {'lr': 0.001, 'module__hidden_layers_dim': [64, 64], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.7965000000000001
# {'lr': 0.001, 'module__hidden_layers_dim': [64, 32], 'module__input_dim': 1000, 'module__num_classes': 4}: 0.8008000000000001

# %%
###########################################################
### [TO COMPLETE]: START ###
print(f"Best score: {outputs.best_score_}")
print(f"Best parameters: {outputs.best_params_}")
### [TO COMPLETE]: END ###
###########################################################
# Out:
# Best score: 0.8210000000000001
# Best parameters: {'lr': 0.001, 'module__hidden_layers_dim': [256, 128], 'module__input_dim': 1000, 'module__num_classes': 4}

# %%
###########################################################
### [TO COMPLETE]: START ###
# Test the best model
from sklearn.metrics import log_loss, accuracy_score

# Get the best model from the performed GridSearchCV
gs_best_model = outputs.best_estimator_
X_slice_test = SliceDataset(test_dataset, idx=1)
Y_slice_test = SliceDataset(test_dataset, idx=0)

# Compute classes probabilities using predict_proba
y_pred_probs = gs_best_model.predict_proba(X_slice_test)

# Compute the cross-entropy loss using log_loss
test_loss = log_loss(Y_slice_test, y_pred_probs)

# Compute the test accuracy
y_pred_labels = gs_best_model.predict(X_slice_test) # predicted labels
test_accuracy = accuracy_score(Y_slice_test, y_pred_labels)

# Print the average test loss and test accuracy
print(f"Test loss: {test_loss:.8f}", end=' ---------- ')
print(f"Test accuracy: {100*test_accuracy:.4f}%")
### [TO COMPLETE]: END ###
###########################################################
# Out:
# Test loss: 0.47726281 ---------- Test accuracy: 83.5000%

# %% [markdown]
# `%ENDCODE`
